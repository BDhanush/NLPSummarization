# %%
import pandas as pd
import networkx as nx
from sklearn.preprocessing import normalize
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from rouge import Rouge

# %%
df1 = pd.read_csv('data\data3.csv')
df2 = pd.read_csv('data\data7.csv')

# Concatenate the dataframes vertically
data = pd.concat([df1, df2], axis=0)

data.dropna(subset=['title', 'abstract'], inplace=True)
# Reset the index of the combined dataframe
data.reset_index(drop=True, inplace=True)
#data = data.head(2000)
# Load the dataset from CSV
#df = pd.read_csv('your_dataset.csv')
df = data
abstracts = df['abstract'].tolist()
titles = df['title'].tolist()

# Initialize ROUGE scorer
rouge = Rouge()

# Preprocess the text data
def preprocess_text(text):
    # Implement any necessary text preprocessing steps
    # Return the preprocessed text
    return text

abstracts = [preprocess_text(abstract) for abstract in abstracts]
titles = [preprocess_text(title) for title in titles]

# Check if the results CSV file exists
try:
    existing_results = pd.read_csv('summary_scores.csv')
    results = existing_results.to_dict('records')
except FileNotFoundError:
    results = []

# Build the text graph
def build_text_graph(sentences):
    # Initialize an empty graph
    graph = nx.Graph()

    # Add nodes to the graph for each sentence
    for i, sentence in enumerate(sentences):
        graph.add_node(i, sentence=sentence)

    # Add edges between sentences based on similarity
    # Implement your similarity measure or use existing algorithms like Cosine Similarity
    # Update the graph with the edge weights

    return graph

# Apply the PageRank algorithm
def apply_pagerank(graph):
    scores = nx.pagerank(graph)
    return scores

# Extract the top-ranked sentences as the summary
def extract_summary(sentences, scores, k=1):
    # Sort sentences based on the PageRank scores
    ranked_sentences = sorted(scores, key=scores.get, reverse=True)
    summary_sentences = ranked_sentences[:k]

    # Retrieve the corresponding sentences from the original list
    summary = [sentences[sentence_index] for sentence_index in summary_sentences]
    return ' '.join(summary)

# %%
# Iterate over each abstract and generate summary
for i, (abstract, title) in enumerate(zip(abstracts, titles)):
    if i == 2000:
        break
    # Build the text graph using abstracts
    text_graph = build_text_graph([abstract])

    # Apply the PageRank algorithm to the text graph
    scores = apply_pagerank(text_graph)

    # Extract the summary
    generated_summary = extract_summary([abstract], scores)

    # Calculate ROUGE scores if the summary is not empty
    if generated_summary and title:
        try:
            scores = rouge.get_scores(generated_summary, title)
            rouge_score = scores[0]['rouge-1']['f']
        except:
            rouge_score = 0.0
    else:
        rouge_score = 0.0

    # Append the result to the list
    result = {'Index': i+1, 'ROUGE Score': rouge_score}
    results.append(result)
    print(result)

    # Convert the results to a DataFrame
    results_df = pd.DataFrame(results)

    # Save the results to the CSV file
    results_df.to_csv('summary_scores.csv', index=False, mode='w' if i == 0 else 'a', header=i == 0)
average_rouge_score = results_df['ROUGE Score'].mean()

# Append the average score to the result
result = {'Index': 'Average', 'ROUGE Score': average_rouge_score}
print(result)
# Out:
# {'Index': 1, 'ROUGE Score': 0.014388488515087245}
# {'Index': 2, 'ROUGE Score': 0.013605440908880677}
# {'Index': 3, 'ROUGE Score': 0.03149606167524341}
# {'Index': 4, 'ROUGE Score': 0.03846153599297353}
# {'Index': 5, 'ROUGE Score': 0.13157894470914133}
# {'Index': 6, 'ROUGE Score': 0.10958903981985363}
# {'Index': 7, 'ROUGE Score': 0.19512194926531828}
# {'Index': 8, 'ROUGE Score': 0.16260162425540353}
# {'Index': 9, 'ROUGE Score': 0.08955223755290712}
# {'Index': 10, 'ROUGE Score': 0.07476635314874666}
# {'Index': 11, 'ROUGE Score': 0.0312499957031256}
# {'Index': 12, 'ROUGE Score': 0.0591715964160919}
# {'Index': 13, 'ROUGE Score': 0.19999999722222223}
# {'Index': 14, 'ROUGE Score': 0.03149606128092266}
# {'Index': 15, 'ROUGE Score': 0.0294117630968859}
# {'Index': 16, 'ROUGE Score': 0.030534349865392517}
# {'Index': 17, 'ROUGE Score': 0.010869562869211284}
# {'Index': 18, 'ROUGE Score': 0.22018348324215137}
# {'Index': 19, 'ROUGE Score': 0.09467455499597353}
# {'Index': 20, 'ROUGE Score': 0.0624999983007813}
# {'Index': 21, 'ROUGE Score': 0.05925925814430729}
# {'Index': 22, 'ROUGE Score': 0.19047618802721092}
# {'Index': 23, 'ROUGE Score': 0.0563380261694109}
# {'Index': 24, 'ROUGE Score': 0.03124999842895516}
# {'Index': 25, 'ROUGE Score': 0.07619047462312928}
# {'Index': 26, 'ROUGE Score': 0.0373831758756224}
# {'Index': 27, 'ROUGE Score': 0.14492753452530982}
# {'Index': 28, 'ROUGE Score': 0.11267605433842494}
# {'Index': 29, 'ROUGE Score': 0.03571428491567462}
# {'Index': 30, 'ROUGE Score': 0.07563025121919358}
# {'Index': 31, 'ROUGE Score': 0.01418439596800976}
# {'Index': 32, 'ROUGE Score': 0.010638296960728917}
# {'Index': 33, 'ROUGE Score': 0.15730336798384045}
# {'Index': 34, 'ROUGE Score': 0.07476635424927942}
# {'Index': 35, 'ROUGE Score': 0.13385826639965281}
# {'Index': 36, 'ROUGE Score': 0.14634146146044022}
# {'Index': 37, 'ROUGE Score': 0.021276594187415235}
# {'Index': 38, 'ROUGE Score': 0.0}
# {'Index': 39, 'ROUGE Score': 0.04166666388888908}
# {'Index': 40, 'ROUGE Score': 0.1351351326040906}
# {'Index': 41, 'ROUGE Score': 0.048780486044021486}
# {'Index': 42, 'ROUGE Score': 0.08620689526753865}
# {'Index': 43, 'ROUGE Score': 0.038961037524034466}
# {'Index': 44, 'ROUGE Score': 0.09836065345874771}
# {'Index': 45, 'ROUGE Score': 0.12213740330050699}
# {'Index': 46, 'ROUGE Score': 0.14814814677640606}
# {'Index': 47, 'ROUGE Score': 0.0659340643303949}
# {'Index': 48, 'ROUGE Score': 0.08092485371913533}
# {'Index': 49, 'ROUGE Score': 0.05555555482667585}
# {'Index': 50, 'ROUGE Score': 0.0689655149895958}
# {'Index': 51, 'ROUGE Score': 0.02919707919228519}
# {'Index': 52, 'ROUGE Score': 0.10638297716613855}
# {'Index': 53, 'ROUGE Score': 0.06315789355346262}
# {'Index': 54, 'ROUGE Score': 0.05555555380015438}
# {'Index': 55, 'ROUGE Score': 0.06417112188738598}
# {'Index': 56, 'ROUGE Score': 0.0983606538336469}
# {'Index': 57, 'ROUGE Score': 0.011428570250449101}
# {'Index': 58, 'ROUGE Score': 0.02816901302122599}
# {'Index': 59, 'ROUGE Score': 0.022727270712810096}
# {'Index': 60, 'ROUGE Score': 0.11881187956474858}
# {'Index': 61, 'ROUGE Score': 0.043478258442816775}
# {'Index': 62, 'ROUGE Score': 0.15238095081360545}
# {'Index': 63, 'ROUGE Score': 0.03999999788800011}
# {'Index': 64, 'ROUGE Score': 0.07526881628338537}
# {'Index': 65, 'ROUGE Score': 0.04166666531467018}
# {'Index': 66, 'ROUGE Score': 0.1818181798428732}
# {'Index': 67, 'ROUGE Score': 0.1217391289920605}
# {'Index': 68, 'ROUGE Score': 0.13333333127222224}
# {'Index': 69, 'ROUGE Score': 0.16666666343820868}
# {'Index': 70, 'ROUGE Score': 0.139999998362}
# {'Index': 71, 'ROUGE Score': 0.04444444380000001}
# {'Index': 72, 'ROUGE Score': 0.07058823238754337}
# {'Index': 73, 'ROUGE Score': 0.04255318970071936}
# {'Index': 74, 'ROUGE Score': 0.0}
# {'Index': 75, 'ROUGE Score': 0.042857141779591865}
# {'Index': 76, 'ROUGE Score': 0.0}
# {'Index': 77, 'ROUGE Score': 0.04444444300987659}
# {'Index': 78, 'ROUGE Score': 0.33802816496726845}
# {'Index': 79, 'ROUGE Score': 0.015624999542236341}
# {'Index': 80, 'ROUGE Score': 0.13333333033888894}
# {'Index': 81, 'ROUGE Score': 0.058252425431237674}
# {'Index': 82, 'ROUGE Score': 0.11538461278106514}
# {'Index': 83, 'ROUGE Score': 0.07407407209876549}
# {'Index': 84, 'ROUGE Score': 0.15999999830755557}
# {'Index': 85, 'ROUGE Score': 0.21686746740600957}
# {'Index': 86, 'ROUGE Score': 0.07317072920880437}
# {'Index': 87, 'ROUGE Score': 0.0}
# {'Index': 88, 'ROUGE Score': 0.34210525983379503}
# {'Index': 89, 'ROUGE Score': 0.13333333064533337}
# {'Index': 90, 'ROUGE Score': 0.05263157628808878}
# {'Index': 91, 'ROUGE Score': 0.29999999651250003}
# {'Index': 92, 'ROUGE Score': 0.20512820276718532}
# {'Index': 93, 'ROUGE Score': 0.04494381805832608}
# {'Index': 94, 'ROUGE Score': 0.15126050238824942}
# {'Index': 95, 'ROUGE Score': 0.019047617480272238}
# {'Index': 96, 'ROUGE Score': 0.08092485440208495}
# {'Index': 97, 'ROUGE Score': 0.014285713208163348}
# {'Index': 98, 'ROUGE Score': 0.1459854001065587}
# {'Index': 99, 'ROUGE Score': 0.08791208562250942}
# {'Index': 100, 'ROUGE Score': 0.06060605907828287}
# {'Index': 101, 'ROUGE Score': 0.017857141230867495}
# {'Index': 102, 'ROUGE Score': 0.021276592648257583}
# {'Index': 103, 'ROUGE Score': 0.03030302865013783}
# {'Index': 104, 'ROUGE Score': 0.2571428544938776}
# {'Index': 105, 'ROUGE Score': 0.08247422495483052}
# {'Index': 106, 'ROUGE Score': 0.0799999991275102}
# {'Index': 107, 'ROUGE Score': 0.045801524689703485}
# {'Index': 108, 'ROUGE Score': 0.1702127634223631}
# {'Index': 109, 'ROUGE Score': 0.0990098995314185}
# {'Index': 110, 'ROUGE Score': 0.2461538439952663}
# {'Index': 111, 'ROUGE Score': 0.17241379013822833}
# {'Index': 112, 'ROUGE Score': 0.08888888543209889}
# {'Index': 113, 'ROUGE Score': 0.18749999817504884}
# {'Index': 114, 'ROUGE Score': 0.09999999745000007}
# {'Index': 115, 'ROUGE Score': 0.030303029298668533}
# {'Index': 116, 'ROUGE Score': 0.14285714040816327}
# {'Index': 117, 'ROUGE Score': 0.043478259777357725}
# {'Index': 118, 'ROUGE Score': 0.015873014546485376}
# {'Index': 119, 'ROUGE Score': 0.1403508745337027}
# {'Index': 120, 'ROUGE Score': 0.19642856951530616}
# {'Index': 121, 'ROUGE Score': 0.030612244209183685}
# {'Index': 122, 'ROUGE Score': 0.07751937755663729}
# {'Index': 123, 'ROUGE Score': 0.10071942264893123}
# {'Index': 124, 'ROUGE Score': 0.09756097168352187}
# {'Index': 125, 'ROUGE Score': 0.06666666486666671}
# {'Index': 126, 'ROUGE Score': 0.11999999704800006}
# {'Index': 127, 'ROUGE Score': 0.014814814522908094}
# {'Index': 128, 'ROUGE Score': 0.09302325358301791}
# {'Index': 129, 'ROUGE Score': 0.09615384473372783}
# {'Index': 130, 'ROUGE Score': 0.04761904453514759}
# {'Index': 131, 'ROUGE Score': 0.10344827348394774}
# {'Index': 132, 'ROUGE Score': 0.0294117630968859}
# {'Index': 133, 'ROUGE Score': 0.16071428408801022}
# {'Index': 134, 'ROUGE Score': 0.09638554082740602}
# {'Index': 135, 'ROUGE Score': 0.1818181791708217}
# {'Index': 136, 'ROUGE Score': 0.3243243209349891}
# {'Index': 137, 'ROUGE Score': 0.3287671198648902}
# {'Index': 138, 'ROUGE Score': 0.1562499983007813}
# {'Index': 139, 'ROUGE Score': 0.14678898931066411}
# {'Index': 140, 'ROUGE Score': 0.01680672173151619}
# {'Index': 141, 'ROUGE Score': 0.037383176679185975}
# {'Index': 142, 'ROUGE Score': 0.0}
# {'Index': 143, 'ROUGE Score': 0.02816901302122599}
# {'Index': 144, 'ROUGE Score': 0.1428571397732427}
# {'Index': 145, 'ROUGE Score': 0.032258062513007404}
# {'Index': 146, 'ROUGE Score': 0.1111111091358025}
# {'Index': 147, 'ROUGE Score': 0.08888888726913582}
# {'Index': 148, 'ROUGE Score': 0.21333332982755562}
# {'Index': 149, 'ROUGE Score': 0.23809523531746032}
# {'Index': 150, 'ROUGE Score': 0.12080536764650242}
# {'Index': 151, 'ROUGE Score': 0.2471910085847747}
# {'Index': 152, 'ROUGE Score': 0.031249997812500156}
# {'Index': 153, 'ROUGE Score': 0.05970148979282704}
# {'Index': 154, 'ROUGE Score': 0.17391303983931955}
# {'Index': 155, 'ROUGE Score': 0.1978021960198044}
# {'Index': 156, 'ROUGE Score': 0.06060605895316809}
# {'Index': 157, 'ROUGE Score': 0.092592590617284}
# {'Index': 158, 'ROUGE Score': 0.07751937778979635}
# {'Index': 159, 'ROUGE Score': 0.2439024348839977}
# {'Index': 160, 'ROUGE Score': 0.0536912736867709}
# {'Index': 161, 'ROUGE Score': 0.04109588913492217}
# {'Index': 162, 'ROUGE Score': 0.19047618802721092}
# {'Index': 163, 'ROUGE Score': 0.033057849452906324}
# {'Index': 164, 'ROUGE Score': 0.15094339366322537}
# {'Index': 165, 'ROUGE Score': 0.022471909051887437}
# {'Index': 166, 'ROUGE Score': 0.09195402170432025}
# {'Index': 167, 'ROUGE Score': 0.057971012904851967}
# {'Index': 168, 'ROUGE Score': 0.023391811764303598}
# {'Index': 169, 'ROUGE Score': 0.15384615139717428}
# {'Index': 170, 'ROUGE Score': 0.04301075129610364}
# {'Index': 171, 'ROUGE Score': 0.10169491329359381}
# {'Index': 172, 'ROUGE Score': 0.05405405256391531}
# {'Index': 173, 'ROUGE Score': 0.03508771714373667}
# {'Index': 174, 'ROUGE Score': 0.03225806330905312}
# {'Index': 175, 'ROUGE Score': 0.0}
# {'Index': 176, 'ROUGE Score': 0.15094339293698833}
# {'Index': 177, 'ROUGE Score': 0.08108107874360854}
# {'Index': 178, 'ROUGE Score': 0.0}
# {'Index': 179, 'ROUGE Score': 0.10810810564077598}
# {'Index': 180, 'ROUGE Score': 0.031249998919813407}
# {'Index': 181, 'ROUGE Score': 0.049999998300781306}
# {'Index': 182, 'ROUGE Score': 0.2535211239515969}
# {'Index': 183, 'ROUGE Score': 0.10714285581632653}
# {'Index': 184, 'ROUGE Score': 0.2337662313172542}
# {'Index': 185, 'ROUGE Score': 0.07207207000405816}
# {'Index': 186, 'ROUGE Score': 0.11363636144886367}
# {'Index': 187, 'ROUGE Score': 0.09677419130072845}
# {'Index': 188, 'ROUGE Score': 0.07547169582057679}
# {'Index': 189, 'ROUGE Score': 0.027027025098612267}
# {'Index': 190, 'ROUGE Score': 0.23684210297783936}
# {'Index': 191, 'ROUGE Score': 0.03960395861190088}
# {'Index': 192, 'ROUGE Score': 0.05128204986193298}
# {'Index': 193, 'ROUGE Score': 0.038095237017687106}
# {'Index': 194, 'ROUGE Score': 0.0232558118983236}
# {'Index': 195, 'ROUGE Score': 0.07407407286179699}
# {'Index': 196, 'ROUGE Score': 0.16470587992802768}
# {'Index': 197, 'ROUGE Score': 0.0}
# {'Index': 198, 'ROUGE Score': 0.34999999680000005}
# {'Index': 199, 'ROUGE Score': 0.12280701566020316}
# {'Index': 200, 'ROUGE Score': 0.07272726975206624}
# {'Index': 201, 'ROUGE Score': 0.21428571135204083}
# {'Index': 202, 'ROUGE Score': 0.08421052513240998}
# {'Index': 203, 'ROUGE Score': 0.0}
# {'Index': 204, 'ROUGE Score': 0.041237111552768706}
# {'Index': 205, 'ROUGE Score': 0.07920791826291547}
# {'Index': 206, 'ROUGE Score': 0.2727272694731405}
# {'Index': 207, 'ROUGE Score': 0.11475409671996777}
# {'Index': 208, 'ROUGE Score': 0.0677966086182132}
# {'Index': 209, 'ROUGE Score': 0.12631578711135738}
# {'Index': 210, 'ROUGE Score': 0.06666666435555564}
# {'Index': 211, 'ROUGE Score': 0.020618554379849344}
# {'Index': 212, 'ROUGE Score': 0.014705881509515621}
# {'Index': 213, 'ROUGE Score': 0.1739130403308129}
# {'Index': 214, 'ROUGE Score': 0.03174602907533406}
# {'Index': 215, 'ROUGE Score': 0.08888888764444446}
# {'Index': 216, 'ROUGE Score': 0.08620689405023788}
# {'Index': 217, 'ROUGE Score': 0.1016949124389544}
# {'Index': 218, 'ROUGE Score': 0.04444444282469141}
# {'Index': 219, 'ROUGE Score': 0.0}
# {'Index': 220, 'ROUGE Score': 0.5555555513117285}
# {'Index': 221, 'ROUGE Score': 0.1714285679020409}
# {'Index': 222, 'ROUGE Score': 0.08108107959094232}
# {'Index': 223, 'ROUGE Score': 0.14285714066964286}
# {'Index': 224, 'ROUGE Score': 0.0}
# {'Index': 225, 'ROUGE Score': 0.1290322568574402}
# {'Index': 226, 'ROUGE Score': 0.04081632438150782}
# {'Index': 227, 'ROUGE Score': 0.06106870101043066}
# {'Index': 228, 'ROUGE Score': 0.06666666542222224}
# {'Index': 229, 'ROUGE Score': 0.04651162585181188}
# {'Index': 230, 'ROUGE Score': 0.20689654918219055}
# {'Index': 231, 'ROUGE Score': 0.03809523637188216}
# {'Index': 232, 'ROUGE Score': 0.0444444424691359}
# {'Index': 233, 'ROUGE Score': 0.025641024220907378}
# {'Index': 234, 'ROUGE Score': 0.0}
# {'Index': 235, 'ROUGE Score': 0.17821781968826583}
# {'Index': 236, 'ROUGE Score': 0.0853658526212076}
# {'Index': 237, 'ROUGE Score': 0.21739130176748583}
# {'Index': 238, 'ROUGE Score': 0.08139534784545702}
# {'Index': 239, 'ROUGE Score': 0.12765957088275248}
# {'Index': 240, 'ROUGE Score': 0.5671641749164625}
# {'Index': 241, 'ROUGE Score': 0.018018016527879356}
# {'Index': 242, 'ROUGE Score': 0.18181817924701563}
# {'Index': 243, 'ROUGE Score': 0.0}
# {'Index': 244, 'ROUGE Score': 0.021505374952017663}
# {'Index': 245, 'ROUGE Score': 0.041666664637586906}
# {'Index': 246, 'ROUGE Score': 0.12962962751200274}
# {'Index': 247, 'ROUGE Score': 0.0}
# {'Index': 248, 'ROUGE Score': 0.23913043235586012}
# {'Index': 249, 'ROUGE Score': 0.025316454292581395}
# {'Index': 250, 'ROUGE Score': 0.6060606016161617}
# {'Index': 251, 'ROUGE Score': 0.0}
# {'Index': 252, 'ROUGE Score': 0.533333328888889}
# {'Index': 253, 'ROUGE Score': 0.263157892323792}
# {'Index': 254, 'ROUGE Score': 0.0}
# {'Index': 255, 'ROUGE Score': 0.14141413992857876}
# {'Index': 256, 'ROUGE Score': 0.0}
# {'Index': 257, 'ROUGE Score': 0.10869565095463139}
# {'Index': 258, 'ROUGE Score': 0.0606060594674013}
# {'Index': 259, 'ROUGE Score': 0.02770083053874664}
# {'Index': 260, 'ROUGE Score': 0.013157893858206428}
# {'Index': 261, 'ROUGE Score': 0.24242423964646465}
# {'Index': 262, 'ROUGE Score': 0.015151514707300287}
# {'Index': 263, 'ROUGE Score': 0.05504587043809446}
# {'Index': 264, 'ROUGE Score': 0.1192052963308627}
# {'Index': 265, 'ROUGE Score': 0.10958903936198164}
# {'Index': 266, 'ROUGE Score': 0.01785714233577808}
# {'Index': 267, 'ROUGE Score': 0.07894736730695985}
# {'Index': 268, 'ROUGE Score': 0.08333333135802475}
# {'Index': 269, 'ROUGE Score': 0.09999999820000001}
# {'Index': 270, 'ROUGE Score': 0.2222222200050391}
# {'Index': 271, 'ROUGE Score': 0.05309734366669282}
# {'Index': 272, 'ROUGE Score': 0.0}
# {'Index': 273, 'ROUGE Score': 0.09523809160997747}
# {'Index': 274, 'ROUGE Score': 0.14285714094387758}
# {'Index': 275, 'ROUGE Score': 0.03508771688519561}
# {'Index': 276, 'ROUGE Score': 0.09160305064040566}
# {'Index': 277, 'ROUGE Score': 0.03333333127222235}
# {'Index': 278, 'ROUGE Score': 0.0}
# {'Index': 279, 'ROUGE Score': 0.1785714267524093}
# {'Index': 280, 'ROUGE Score': 0.22641509152011394}
# {'Index': 281, 'ROUGE Score': 0.08080807883277222}
# {'Index': 282, 'ROUGE Score': 0.0434782600378072}
# {'Index': 283, 'ROUGE Score': 0.10666666416355562}
# {'Index': 284, 'ROUGE Score': 0.0}
# {'Index': 285, 'ROUGE Score': 0.0857142841469388}
# {'Index': 286, 'ROUGE Score': 0.05555555316358035}
# {'Index': 287, 'ROUGE Score': 0.19354838439125913}
# {'Index': 288, 'ROUGE Score': 0.01492537241590558}
# {'Index': 289, 'ROUGE Score': 0.11764705721453288}
# {'Index': 290, 'ROUGE Score': 0.1318681299118464}
# {'Index': 291, 'ROUGE Score': 0.03333333208888894}
# {'Index': 292, 'ROUGE Score': 0.07142856734693902}
# {'Index': 293, 'ROUGE Score': 0.09433962108757565}
# {'Index': 294, 'ROUGE Score': 0.10256410032873114}
# {'Index': 295, 'ROUGE Score': 0.08791208562250942}
# {'Index': 296, 'ROUGE Score': 0.04123711171856739}
# {'Index': 297, 'ROUGE Score': 0.0784313704728951}
# {'Index': 298, 'ROUGE Score': 0.16216215944485027}
# {'Index': 299, 'ROUGE Score': 0.019999999050000043}
# {'Index': 300, 'ROUGE Score': 0.052910052196747014}
# {'Index': 301, 'ROUGE Score': 0.07228915488459868}
# {'Index': 302, 'ROUGE Score': 0.043478258601134336}
# {'Index': 303, 'ROUGE Score': 0.0}
# {'Index': 304, 'ROUGE Score': 0.10909090758842976}
# {'Index': 305, 'ROUGE Score': 0.013793102529369859}
# {'Index': 306, 'ROUGE Score': 0.044776118412786836}
# {'Index': 307, 'ROUGE Score': 0.0}
# {'Index': 308, 'ROUGE Score': 0.07228915508201483}
# {'Index': 309, 'ROUGE Score': 0.08163265156184926}
# {'Index': 310, 'ROUGE Score': 0.16216215867218578}
# {'Index': 311, 'ROUGE Score': 0.044444442298765534}
# {'Index': 312, 'ROUGE Score': 0.020202018716457618}
# {'Index': 313, 'ROUGE Score': 0.03508771597414621}
# {'Index': 314, 'ROUGE Score': 0.14814814665130313}
# {'Index': 315, 'ROUGE Score': 0.18181817992194677}
# {'Index': 316, 'ROUGE Score': 0.03809523621950123}
# {'Index': 317, 'ROUGE Score': 0.03508771714373667}
# {'Index': 318, 'ROUGE Score': 0.14876032879174922}
# {'Index': 319, 'ROUGE Score': 0.03921568405036537}
# {'Index': 320, 'ROUGE Score': 0.057692306605029595}
# {'Index': 321, 'ROUGE Score': 0.03174603015243142}
# {'Index': 322, 'ROUGE Score': 0.034782607252930114}
# {'Index': 323, 'ROUGE Score': 0.017391303757655973}
# {'Index': 324, 'ROUGE Score': 0.05298013132932769}
# {'Index': 325, 'ROUGE Score': 0.1224489780924615}
# {'Index': 326, 'ROUGE Score': 0.16129032057752343}
# {'Index': 327, 'ROUGE Score': 0.07142856980229596}
# {'Index': 328, 'ROUGE Score': 0.12121212007346191}
# {'Index': 329, 'ROUGE Score': 0.0909090889652893}
# {'Index': 330, 'ROUGE Score': 0.15730336845347812}
# {'Index': 331, 'ROUGE Score': 0.15624999695312503}
# {'Index': 332, 'ROUGE Score': 0.10232558009734993}
# {'Index': 333, 'ROUGE Score': 0.0854700837665279}
# {'Index': 334, 'ROUGE Score': 0.05882352650519045}
# {'Index': 335, 'ROUGE Score': 0.0540540530314098}
# {'Index': 336, 'ROUGE Score': 0.07317072903926243}
# {'Index': 337, 'ROUGE Score': 0.10204081465847564}
# {'Index': 338, 'ROUGE Score': 0.013513512490869324}
# {'Index': 339, 'ROUGE Score': 0.07692307431952672}
# {'Index': 340, 'ROUGE Score': 0.1481481458916324}
# {'Index': 341, 'ROUGE Score': 0.03238866326541987}
# {'Index': 342, 'ROUGE Score': 0.18867924177999293}
# {'Index': 343, 'ROUGE Score': 0.05063290937349791}
# {'Index': 344, 'ROUGE Score': 0.08988763828304512}
# {'Index': 345, 'ROUGE Score': 0.23529411455449828}
# {'Index': 346, 'ROUGE Score': 0.07142856970521545}
# {'Index': 347, 'ROUGE Score': 0.05594405429116344}
# {'Index': 348, 'ROUGE Score': 0.4102564064431296}
# {'Index': 349, 'ROUGE Score': 0.06779660782533764}
# {'Index': 350, 'ROUGE Score': 0.10526315650404207}
# {'Index': 351, 'ROUGE Score': 0.019230767492603707}
# {'Index': 352, 'ROUGE Score': 0.05607476408070583}
# {'Index': 353, 'ROUGE Score': 0.1282051250986194}
# {'Index': 354, 'ROUGE Score': 0.05228758059207999}
# {'Index': 355, 'ROUGE Score': 0.07999999773800007}
# {'Index': 356, 'ROUGE Score': 0.0594059389706892}
# {'Index': 357, 'ROUGE Score': 0.020725388195119338}
# {'Index': 358, 'ROUGE Score': 0.1720430090045092}
# {'Index': 359, 'ROUGE Score': 0.384615380930309}
# {'Index': 360, 'ROUGE Score': 0.023809522902494367}
# {'Index': 361, 'ROUGE Score': 0.013422817539750581}
# {'Index': 362, 'ROUGE Score': 0.0806451598074922}
# {'Index': 363, 'ROUGE Score': 0.1923076904160503}
# {'Index': 364, 'ROUGE Score': 0.02352941025328729}
# {'Index': 365, 'ROUGE Score': 0.11363636217200414}
# {'Index': 366, 'ROUGE Score': 0.017429193431965872}
# {'Index': 367, 'ROUGE Score': 0.06382978516749667}
# {'Index': 368, 'ROUGE Score': 0.03846153672337286}
# {'Index': 369, 'ROUGE Score': 0.22222222007654327}
# {'Index': 370, 'ROUGE Score': 0.1369862994182774}
# {'Index': 371, 'ROUGE Score': 0.08383233441715372}
# {'Index': 372, 'ROUGE Score': 0.05988023741260003}
# {'Index': 373, 'ROUGE Score': 0.062499996762695485}
# {'Index': 374, 'ROUGE Score': 0.043478259841682444}
# {'Index': 375, 'ROUGE Score': 0.06976744036506224}
# {'Index': 376, 'ROUGE Score': 0.031249997812500156}
# {'Index': 377, 'ROUGE Score': 0.2608695627389204}
# {'Index': 378, 'ROUGE Score': 0.09599999866368002}
# {'Index': 379, 'ROUGE Score': 0.0}
# {'Index': 380, 'ROUGE Score': 0.11214953116953448}
# {'Index': 381, 'ROUGE Score': 0.09677419180020813}
# {'Index': 382, 'ROUGE Score': 0.1720430083477859}
# {'Index': 383, 'ROUGE Score': 0.04545454458677687}
# {'Index': 384, 'ROUGE Score': 0.07228915450718543}
# {'Index': 385, 'ROUGE Score': 0.03960395830212735}
# {'Index': 386, 'ROUGE Score': 0.018264839478743175}
# {'Index': 387, 'ROUGE Score': 0.10144927414303719}
# {'Index': 388, 'ROUGE Score': 0.16129032057752343}
# {'Index': 389, 'ROUGE Score': 0.024999998612500077}
# {'Index': 390, 'ROUGE Score': 0.30769230324786334}
# {'Index': 391, 'ROUGE Score': 0.061224488127863436}
# {'Index': 392, 'ROUGE Score': 0.10526315658971994}
# {'Index': 393, 'ROUGE Score': 0.03921568528343802}
# {'Index': 394, 'ROUGE Score': 0.029411763343425667}
# {'Index': 395, 'ROUGE Score': 0.10869564889650293}
# {'Index': 396, 'ROUGE Score': 0.07017543729147431}
# {'Index': 397, 'ROUGE Score': 0.09195402095389092}
# {'Index': 398, 'ROUGE Score': 0.024691356049382874}
# {'Index': 399, 'ROUGE Score': 0.1555555539358025}
# {'Index': 400, 'ROUGE Score': 0.15555555324444445}
# {'Index': 401, 'ROUGE Score': 0.0}
# {'Index': 402, 'ROUGE Score': 0.0946745536920977}
# {'Index': 403, 'ROUGE Score': 0.015503874805600714}
# {'Index': 404, 'ROUGE Score': 0.23255813713358575}
# {'Index': 405, 'ROUGE Score': 0.12371133803804871}
# {'Index': 406, 'ROUGE Score': 0.10810810597151209}
# {'Index': 407, 'ROUGE Score': 0.019230767492603707}
# {'Index': 408, 'ROUGE Score': 0.19565217180765598}
# {'Index': 409, 'ROUGE Score': 0.1481481456241427}
# {'Index': 410, 'ROUGE Score': 0.05882352711505199}
# {'Index': 411, 'ROUGE Score': 0.04999999820000006}
# {'Index': 412, 'ROUGE Score': 0.0}
# {'Index': 413, 'ROUGE Score': 0.06849314977200226}
# {'Index': 414, 'ROUGE Score': 0.009615384055103584}
# {'Index': 415, 'ROUGE Score': 0.24390243559785843}
# {'Index': 416, 'ROUGE Score': 0.07058823340069209}
# {'Index': 417, 'ROUGE Score': 0.1194029839518824}
# {'Index': 418, 'ROUGE Score': 0.1265822762698286}
# {'Index': 419, 'ROUGE Score': 0.05405405319373428}
# {'Index': 420, 'ROUGE Score': 0.08080807932251814}
# {'Index': 421, 'ROUGE Score': 0.028915662226273772}
# {'Index': 422, 'ROUGE Score': 0.019230767492603707}
# {'Index': 423, 'ROUGE Score': 0.1772151863547509}
# {'Index': 424, 'ROUGE Score': 0.0983606529965064}
# {'Index': 425, 'ROUGE Score': 0.06349206216553292}
# {'Index': 426, 'ROUGE Score': 0.07499999840312503}
# {'Index': 427, 'ROUGE Score': 0.2093023231800974}
# {'Index': 428, 'ROUGE Score': 0.02173912940689986}
# {'Index': 429, 'ROUGE Score': 0.08928571280771685}
# {'Index': 430, 'ROUGE Score': 0.12844036577055806}
# {'Index': 431, 'ROUGE Score': 0.05357142638392866}
# {'Index': 432, 'ROUGE Score': 0.015267174698444196}
# {'Index': 433, 'ROUGE Score': 0.09090908925619837}
# {'Index': 434, 'ROUGE Score': 0.048484847240404076}
# {'Index': 435, 'ROUGE Score': 0.12499999762812504}
# {'Index': 436, 'ROUGE Score': 0.05084745666187878}
# {'Index': 437, 'ROUGE Score': 0.09900989860209788}
# {'Index': 438, 'ROUGE Score': 0.15217391145557654}
# {'Index': 439, 'ROUGE Score': 0.062499997812500076}
# {'Index': 440, 'ROUGE Score': 0.08510638197148032}
# {'Index': 441, 'ROUGE Score': 0.01869158772643905}
# {'Index': 442, 'ROUGE Score': 0.186046509226609}
# {'Index': 443, 'ROUGE Score': 0.1333333316408889}
# {'Index': 444, 'ROUGE Score': 0.1562499983007813}
# {'Index': 445, 'ROUGE Score': 0.22222221786313068}
# {'Index': 446, 'ROUGE Score': 0.05882352711505199}
# {'Index': 447, 'ROUGE Score': 0.14117646625328734}
# {'Index': 448, 'ROUGE Score': 0.07722007523143667}
# {'Index': 449, 'ROUGE Score': 0.019230768143491183}
# {'Index': 450, 'ROUGE Score': 0.17777777580246917}
# {'Index': 451, 'ROUGE Score': 0.021505375326627406}
# {'Index': 452, 'ROUGE Score': 0.04597700945963809}
# {'Index': 453, 'ROUGE Score': 0.07228915322978678}
# {'Index': 454, 'ROUGE Score': 0.03389830325768467}
# {'Index': 455, 'ROUGE Score': 0.04081632366305726}
# {'Index': 456, 'ROUGE Score': 0.12698412453514743}
# {'Index': 457, 'ROUGE Score': 0.19047618802721092}
# {'Index': 458, 'ROUGE Score': 0.06521738676748616}
# {'Index': 459, 'ROUGE Score': 0.03296703232942882}
# {'Index': 460, 'ROUGE Score': 0.016806721581809268}
# {'Index': 461, 'ROUGE Score': 0.0}
# {'Index': 462, 'ROUGE Score': 0.1366459603734424}
# {'Index': 463, 'ROUGE Score': 0.39999999680000003}
# {'Index': 464, 'ROUGE Score': 0.0634920612748804}
# {'Index': 465, 'ROUGE Score': 0.07766990042416824}
# {'Index': 466, 'ROUGE Score': 0.18867924313100748}
# {'Index': 467, 'ROUGE Score': 0.028985506283343863}
# {'Index': 468, 'ROUGE Score': 0.01869158789413927}
# {'Index': 469, 'ROUGE Score': 0.06282722404539351}
# {'Index': 470, 'ROUGE Score': 0.0}
# {'Index': 471, 'ROUGE Score': 0.08510638044363973}
# {'Index': 472, 'ROUGE Score': 0.1758241736988287}
# {'Index': 473, 'ROUGE Score': 0.04255318895427811}
# {'Index': 474, 'ROUGE Score': 0.03797468275536774}
# {'Index': 475, 'ROUGE Score': 0.039999997592000146}
# {'Index': 476, 'ROUGE Score': 0.11428571271836736}
# {'Index': 477, 'ROUGE Score': 0.10852712972778081}
# {'Index': 478, 'ROUGE Score': 0.14432989539377195}
# {'Index': 479, 'ROUGE Score': 0.21951219262343843}
# {'Index': 480, 'ROUGE Score': 0.042553190110909966}
# {'Index': 481, 'ROUGE Score': 0.07407407209876549}
# {'Index': 482, 'ROUGE Score': 0.2439024348839977}
# {'Index': 483, 'ROUGE Score': 0.0769230752892834}
# {'Index': 484, 'ROUGE Score': 0.0}
# {'Index': 485, 'ROUGE Score': 0.045454543926767725}
# {'Index': 486, 'ROUGE Score': 0.05555555372599457}
# {'Index': 487, 'ROUGE Score': 0.21212120955004593}
# {'Index': 488, 'ROUGE Score': 0.018264839478743175}
# {'Index': 489, 'ROUGE Score': 0.07547169625311503}
# {'Index': 490, 'ROUGE Score': 0.03333333055555578}
# {'Index': 491, 'ROUGE Score': 0.18823529222422147}
# {'Index': 492, 'ROUGE Score': 0.027397257526740753}
# {'Index': 493, 'ROUGE Score': 0.1874999973632813}
# {'Index': 494, 'ROUGE Score': 0.04040403926538112}
# {'Index': 495, 'ROUGE Score': 0.10309278103517913}
# {'Index': 496, 'ROUGE Score': 0.1081081050401754}
# {'Index': 497, 'ROUGE Score': 0.06504064802432424}
# {'Index': 498, 'ROUGE Score': 0.2666666632098766}
# {'Index': 499, 'ROUGE Score': 0.10638297699185154}
# {'Index': 500, 'ROUGE Score': 0.0}
# {'Index': 501, 'ROUGE Score': 0.1724137912485137}
# {'Index': 502, 'ROUGE Score': 0.05263157594182843}
# {'Index': 503, 'ROUGE Score': 0.00431034448870395}
# {'Index': 504, 'ROUGE Score': 0.16666666439058955}
# {'Index': 505, 'ROUGE Score': 0.02830188606621575}
# {'Index': 506, 'ROUGE Score': 0.0}
# {'Index': 507, 'ROUGE Score': 0.03448275718935797}
# {'Index': 508, 'ROUGE Score': 0.34285713933061224}
# {'Index': 509, 'ROUGE Score': 0.07100591594271911}
# {'Index': 510, 'ROUGE Score': 0.0}
# {'Index': 511, 'ROUGE Score': 0.07692307583579881}
# {'Index': 512, 'ROUGE Score': 0.0}
# {'Index': 513, 'ROUGE Score': 0.0350877186211142}
# {'Index': 514, 'ROUGE Score': 0.0}
# {'Index': 515, 'ROUGE Score': 0.05882352813341026}
# {'Index': 516, 'ROUGE Score': 0.031914893200543235}
# {'Index': 517, 'ROUGE Score': 0.0}
# {'Index': 518, 'ROUGE Score': 0.03636363471074388}
# {'Index': 519, 'ROUGE Score': 0.179999997738}
# {'Index': 520, 'ROUGE Score': 0.10606060416437102}
# {'Index': 521, 'ROUGE Score': 0.10619468865220459}
# {'Index': 522, 'ROUGE Score': 0.04761904602544726}
# {'Index': 523, 'ROUGE Score': 0.11764705751141871}
# {'Index': 524, 'ROUGE Score': 0.0869565194706995}
# {'Index': 525, 'ROUGE Score': 0.003696857451628237}
# {'Index': 526, 'ROUGE Score': 0.13043478002835543}
# {'Index': 527, 'ROUGE Score': 0.04761904609126989}
# {'Index': 528, 'ROUGE Score': 0.0504201671096674}
# {'Index': 529, 'ROUGE Score': 0.02739725876524685}
# {'Index': 530, 'ROUGE Score': 0.0}
# {'Index': 531, 'ROUGE Score': 0.0277777767283951}
# {'Index': 532, 'ROUGE Score': 0.026666665776888917}
# {'Index': 533, 'ROUGE Score': 0.1578947347541551}
# {'Index': 534, 'ROUGE Score': 0.09523809332482996}
# {'Index': 535, 'ROUGE Score': 0.04878048548185616}
# {'Index': 536, 'ROUGE Score': 0.08108107915266621}
# {'Index': 537, 'ROUGE Score': 0.19642856951530616}
# {'Index': 538, 'ROUGE Score': 0.13888888713348768}
# {'Index': 539, 'ROUGE Score': 0.03571428438775515}
# {'Index': 540, 'ROUGE Score': 0.019801978907950286}
# {'Index': 541, 'ROUGE Score': 0.017094016275841957}
# {'Index': 542, 'ROUGE Score': 0.0}
# {'Index': 543, 'ROUGE Score': 0.0547945168324266}
# {'Index': 544, 'ROUGE Score': 0.09230768929704153}
# {'Index': 545, 'ROUGE Score': 0.033333331533333434}
# {'Index': 546, 'ROUGE Score': 0.07619047431473927}
# {'Index': 547, 'ROUGE Score': 0.14285713785714302}
# {'Index': 548, 'ROUGE Score': 0.029411761993944886}
# {'Index': 549, 'ROUGE Score': 0.16666666388888893}
# {'Index': 550, 'ROUGE Score': 0.023346302826083687}
# {'Index': 551, 'ROUGE Score': 0.02888086579728657}
# {'Index': 552, 'ROUGE Score': 0.137931032812789}
# {'Index': 553, 'ROUGE Score': 0.07317072920880437}
# {'Index': 554, 'ROUGE Score': 0.08163264936276568}
# {'Index': 555, 'ROUGE Score': 0.0}
# {'Index': 556, 'ROUGE Score': 0.021052630036565212}
# {'Index': 557, 'ROUGE Score': 0.0}
# {'Index': 558, 'ROUGE Score': 0.1538461512426036}
# {'Index': 559, 'ROUGE Score': 0.0}
# {'Index': 560, 'ROUGE Score': 0.04651162647677427}
# {'Index': 561, 'ROUGE Score': 0.0645161255359003}
# {'Index': 562, 'ROUGE Score': 0.3333333302006173}
# {'Index': 563, 'ROUGE Score': 0.10256409996055234}
# {'Index': 564, 'ROUGE Score': 0.23999999788800003}
# {'Index': 565, 'ROUGE Score': 0.06106870075170449}
# {'Index': 566, 'ROUGE Score': 0.023668637939848098}
# {'Index': 567, 'ROUGE Score': 0.0}
# {'Index': 568, 'ROUGE Score': 0.039473682756232746}
# {'Index': 569, 'ROUGE Score': 0.11363636217200414}
# {'Index': 570, 'ROUGE Score': 0.21052631313019393}
# {'Index': 571, 'ROUGE Score': 0.03174603015243142}
# {'Index': 572, 'ROUGE Score': 0.04166666496744798}
# {'Index': 573, 'ROUGE Score': 0.1518987312610159}
# {'Index': 574, 'ROUGE Score': 0.1388888867013889}
# {'Index': 575, 'ROUGE Score': 0.1333333314013889}
# {'Index': 576, 'ROUGE Score': 0.052173911748960335}
# {'Index': 577, 'ROUGE Score': 0.1523809503564626}
# {'Index': 578, 'ROUGE Score': 0.045977010616990374}
# {'Index': 579, 'ROUGE Score': 0.20289854867464818}
# {'Index': 580, 'ROUGE Score': 0.13253011903832196}
# {'Index': 581, 'ROUGE Score': 0.08421052410858731}
# {'Index': 582, 'ROUGE Score': 0.13333333102222228}
# {'Index': 583, 'ROUGE Score': 0.15999999836200002}
# {'Index': 584, 'ROUGE Score': 0.005263157635041564}
# {'Index': 585, 'ROUGE Score': 0.15053763283616603}
# {'Index': 586, 'ROUGE Score': 0.04651162585181188}
# {'Index': 587, 'ROUGE Score': 0.11764705674740487}
# {'Index': 588, 'ROUGE Score': 0.08080807899193965}
# {'Index': 589, 'ROUGE Score': 0.05660377115521549}
# {'Index': 590, 'ROUGE Score': 0.09433962078141689}
# {'Index': 591, 'ROUGE Score': 0.04444444282469141}
# {'Index': 592, 'ROUGE Score': 0.16901408188851422}
# {'Index': 593, 'ROUGE Score': 0.11594202611216138}
# {'Index': 594, 'ROUGE Score': 0.09999999820000001}
# {'Index': 595, 'ROUGE Score': 0.14285714102457311}
# {'Index': 596, 'ROUGE Score': 0.026315788019390662}
# {'Index': 597, 'ROUGE Score': 0.05882352756487896}
# {'Index': 598, 'ROUGE Score': 0.03529411603806236}
# {'Index': 599, 'ROUGE Score': 0.018518517635459576}
# {'Index': 600, 'ROUGE Score': 0.1052631562942444}
# {'Index': 601, 'ROUGE Score': 0.01739130351606809}
# {'Index': 602, 'ROUGE Score': 0.07741935363163373}
# {'Index': 603, 'ROUGE Score': 0.20833333084201391}
# {'Index': 604, 'ROUGE Score': 0.0}
# {'Index': 605, 'ROUGE Score': 0.10084033418826356}
# {'Index': 606, 'ROUGE Score': 0.08888888726913582}
# {'Index': 607, 'ROUGE Score': 0.07633587595361581}
# {'Index': 608, 'ROUGE Score': 0.04166666496744798}
# {'Index': 609, 'ROUGE Score': 0.09411764554740484}
# {'Index': 610, 'ROUGE Score': 0.07920791933339871}
# {'Index': 611, 'ROUGE Score': 0.020833332534722252}
# {'Index': 612, 'ROUGE Score': 0.16666666494331067}
# {'Index': 613, 'ROUGE Score': 0.09433962108757565}
# {'Index': 614, 'ROUGE Score': 0.015873014149660053}
# {'Index': 615, 'ROUGE Score': 0.2197802168820191}
# {'Index': 616, 'ROUGE Score': 0.13793103244814375}
# {'Index': 617, 'ROUGE Score': 0.1228070159433672}
# {'Index': 618, 'ROUGE Score': 0.13043477875236306}
# {'Index': 619, 'ROUGE Score': 0.0}
# {'Index': 620, 'ROUGE Score': 0.041666664029948085}
# {'Index': 621, 'ROUGE Score': 0.08588956950882608}
# {'Index': 622, 'ROUGE Score': 0.0}
# {'Index': 623, 'ROUGE Score': 0.0}
# {'Index': 624, 'ROUGE Score': 0.0}
# {'Index': 625, 'ROUGE Score': 0.17808218972321263}
# {'Index': 626, 'ROUGE Score': 0.0930232547187669}
# {'Index': 627, 'ROUGE Score': 0.1470588214532872}
# {'Index': 628, 'ROUGE Score': 0.0}
# {'Index': 629, 'ROUGE Score': 0.0}
# {'Index': 630, 'ROUGE Score': 0.08695652015122875}
# {'Index': 631, 'ROUGE Score': 0.02352940917370271}
# {'Index': 632, 'ROUGE Score': 0.07894736707842799}
# {'Index': 633, 'ROUGE Score': 0.09677419234131114}
# {'Index': 634, 'ROUGE Score': 0.0}
# {'Index': 635, 'ROUGE Score': 0.14285714066964286}
# {'Index': 636, 'ROUGE Score': 0.08888888790562414}
# {'Index': 637, 'ROUGE Score': 0.06818181634555791}
# {'Index': 638, 'ROUGE Score': 0.2127659540968765}
# {'Index': 639, 'ROUGE Score': 0.025641024007232185}
# {'Index': 640, 'ROUGE Score': 0.020512819916370828}
# {'Index': 641, 'ROUGE Score': 0.02298850353811621}
# {'Index': 642, 'ROUGE Score': 0.0}
# {'Index': 643, 'ROUGE Score': 0.10169491384515945}
# {'Index': 644, 'ROUGE Score': 0.060606059291909015}
# {'Index': 645, 'ROUGE Score': 0.10958903873146937}
# {'Index': 646, 'ROUGE Score': 0.17948717764628536}
# {'Index': 647, 'ROUGE Score': 0.1081081034039447}
# {'Index': 648, 'ROUGE Score': 0.06666666500138893}
# {'Index': 649, 'ROUGE Score': 0.09467455509961137}
# {'Index': 650, 'ROUGE Score': 0.1565217375425331}
# {'Index': 651, 'ROUGE Score': 0.06976743980530022}
# {'Index': 652, 'ROUGE Score': 0.0}
# {'Index': 653, 'ROUGE Score': 0.05594405384908805}
# {'Index': 654, 'ROUGE Score': 0.06976743998647923}
# {'Index': 655, 'ROUGE Score': 0.09090908833792477}
# {'Index': 656, 'ROUGE Score': 0.09411764554740484}
# {'Index': 657, 'ROUGE Score': 0.07339449389782009}
# {'Index': 658, 'ROUGE Score': 0.10638297699185154}
# {'Index': 659, 'ROUGE Score': 0.062499998003125064}
# {'Index': 660, 'ROUGE Score': 0.047244092650505366}
# {'Index': 661, 'ROUGE Score': 0.01739130261776955}
# {'Index': 662, 'ROUGE Score': 0.13888888575617292}
# {'Index': 663, 'ROUGE Score': 0.21428571036352043}
# {'Index': 664, 'ROUGE Score': 0.0}
# {'Index': 665, 'ROUGE Score': 0.16842105074792246}
# {'Index': 666, 'ROUGE Score': 0.011904761215986433}
# {'Index': 667, 'ROUGE Score': 0.07999999745000008}
# {'Index': 668, 'ROUGE Score': 0.23529411535034603}
# {'Index': 669, 'ROUGE Score': 0.057692306436760384}
# {'Index': 670, 'ROUGE Score': 0.01785714168526794}
# {'Index': 671, 'ROUGE Score': 0.0810810785500366}
# {'Index': 672, 'ROUGE Score': 0.0}
# {'Index': 673, 'ROUGE Score': 0.0653594759024307}
# {'Index': 674, 'ROUGE Score': 0.08333333216145836}
# {'Index': 675, 'ROUGE Score': 0.09691629847969105}
# {'Index': 676, 'ROUGE Score': 0.03389830274059195}
# {'Index': 677, 'ROUGE Score': 0.06167400735042407}
# {'Index': 678, 'ROUGE Score': 0.04419889418271727}
# {'Index': 679, 'ROUGE Score': 0.24113474894824208}
# {'Index': 680, 'ROUGE Score': 0.16666666253472232}
# {'Index': 681, 'ROUGE Score': 0.02352940933979264}
# {'Index': 682, 'ROUGE Score': 0.06521739008506619}
# {'Index': 683, 'ROUGE Score': 0.05882352865820838}
# {'Index': 684, 'ROUGE Score': 0.06153845998934915}
# {'Index': 685, 'ROUGE Score': 0.04166666480034731}
# {'Index': 686, 'ROUGE Score': 0.020833332161458402}
# {'Index': 687, 'ROUGE Score': 0.0377358471965113}
# {'Index': 688, 'ROUGE Score': 0.23636363375041322}
# {'Index': 689, 'ROUGE Score': 0.08247422601339145}
# {'Index': 690, 'ROUGE Score': 0.1311475392098898}
# {'Index': 691, 'ROUGE Score': 0.08571428391428575}
# {'Index': 692, 'ROUGE Score': 0.06349206203073825}
# {'Index': 693, 'ROUGE Score': 0.24657534030399703}
# {'Index': 694, 'ROUGE Score': 0.08474576062051141}
# {'Index': 695, 'ROUGE Score': 0.08823529140570943}
# {'Index': 696, 'ROUGE Score': 0.0}
# {'Index': 697, 'ROUGE Score': 0.10144927401806343}
# {'Index': 698, 'ROUGE Score': 0.29411764455017303}
# {'Index': 699, 'ROUGE Score': 0.393442619414136}
# {'Index': 700, 'ROUGE Score': 0.17741935181711763}
# {'Index': 701, 'ROUGE Score': 0.10526315560941835}
# {'Index': 702, 'ROUGE Score': 0.2499999958680556}
# {'Index': 703, 'ROUGE Score': 0.05479451881403647}
# {'Index': 704, 'ROUGE Score': 0.07407407121475396}
# {'Index': 705, 'ROUGE Score': 0.038461536420118445}
# {'Index': 706, 'ROUGE Score': 0.03636363549586779}
# {'Index': 707, 'ROUGE Score': 0.11764705746107267}
# {'Index': 708, 'ROUGE Score': 0.08860759311648778}
# {'Index': 709, 'ROUGE Score': 0.03571428438775515}
# {'Index': 710, 'ROUGE Score': 0.0}
# {'Index': 711, 'ROUGE Score': 0.05555555358024698}
# {'Index': 712, 'ROUGE Score': 0.09523809418871253}
# {'Index': 713, 'ROUGE Score': 0.01739130320453694}
# {'Index': 714, 'ROUGE Score': 0.1944444418557099}
# {'Index': 715, 'ROUGE Score': 0.09022556304822207}
# {'Index': 716, 'ROUGE Score': 0.07142856951530618}
# {'Index': 717, 'ROUGE Score': 0.13793103120095132}
# {'Index': 718, 'ROUGE Score': 0.0}
# {'Index': 719, 'ROUGE Score': 0.10084033488030508}
# {'Index': 720, 'ROUGE Score': 0.0}
# {'Index': 721, 'ROUGE Score': 0.06666666411666677}
# {'Index': 722, 'ROUGE Score': 0.08695652015122875}
# {'Index': 723, 'ROUGE Score': 0.09756097277810835}
# {'Index': 724, 'ROUGE Score': 0.11594202630539807}
# {'Index': 725, 'ROUGE Score': 0.11627906688750683}
# {'Index': 726, 'ROUGE Score': 0.02797202667123093}
# {'Index': 727, 'ROUGE Score': 0.03809523685079368}
# {'Index': 728, 'ROUGE Score': 0.06451612702913637}
# {'Index': 729, 'ROUGE Score': 0.12903225671826224}
# {'Index': 730, 'ROUGE Score': 0.12121211896809}
# {'Index': 731, 'ROUGE Score': 0.05263157666204997}
# {'Index': 732, 'ROUGE Score': 0.12121211972655854}
# {'Index': 733, 'ROUGE Score': 0.2857142832653061}
# {'Index': 734, 'ROUGE Score': 0.04278074774686152}
# {'Index': 735, 'ROUGE Score': 0.0}
# {'Index': 736, 'ROUGE Score': 0.16326530428987923}
# {'Index': 737, 'ROUGE Score': 0.07812499793090825}
# {'Index': 738, 'ROUGE Score': 0.0}
# {'Index': 739, 'ROUGE Score': 0.16438355927941453}
# {'Index': 740, 'ROUGE Score': 0.07142856767857161}
# {'Index': 741, 'ROUGE Score': 0.06521738936672974}
# {'Index': 742, 'ROUGE Score': 0.01869158756223259}
# {'Index': 743, 'ROUGE Score': 0.02499999927812502}
# {'Index': 744, 'ROUGE Score': 0.2222222202469136}
# {'Index': 745, 'ROUGE Score': 0.10666666363022231}
# {'Index': 746, 'ROUGE Score': 0.1584158393412411}
# {'Index': 747, 'ROUGE Score': 0.075471694054824}
# {'Index': 748, 'ROUGE Score': 0.05957446727025804}
# {'Index': 749, 'ROUGE Score': 0.27692307453727816}
# {'Index': 750, 'ROUGE Score': 0.025641024007232185}
# {'Index': 751, 'ROUGE Score': 0.1374045780082746}
# {'Index': 752, 'ROUGE Score': 0.31578947021121884}
# {'Index': 753, 'ROUGE Score': 0.17821781999803943}
# {'Index': 754, 'ROUGE Score': 0.019417474630973767}
# {'Index': 755, 'ROUGE Score': 0.06060605933539948}
# {'Index': 756, 'ROUGE Score': 0.2372881327779374}
# {'Index': 757, 'ROUGE Score': 0.019900496933244242}
# {'Index': 758, 'ROUGE Score': 0.06956521624801514}
# {'Index': 759, 'ROUGE Score': 0.06289308091926743}
# {'Index': 760, 'ROUGE Score': 0.019417473820341407}
# {'Index': 761, 'ROUGE Score': 0.017699113430965766}
# {'Index': 762, 'ROUGE Score': 0.1818181780681819}
# {'Index': 763, 'ROUGE Score': 0.33333332932098775}
# {'Index': 764, 'ROUGE Score': 0.016393441256382806}
# {'Index': 765, 'ROUGE Score': 0.08421052410858731}
# {'Index': 766, 'ROUGE Score': 0.02580645098855361}
# {'Index': 767, 'ROUGE Score': 0.04545454472566576}
# {'Index': 768, 'ROUGE Score': 0.028571426330612427}
# {'Index': 769, 'ROUGE Score': 0.09756097365556221}
# {'Index': 770, 'ROUGE Score': 0.08510638178361252}
# {'Index': 771, 'ROUGE Score': 0.08510638178361252}
# {'Index': 772, 'ROUGE Score': 0.0}
# {'Index': 773, 'ROUGE Score': 0.13461538257396452}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19560/1095931277.py in <module>
#      25     result = {'Index': i+1, 'ROUGE Score': rouge_score}
#      26     results.append(result)
# ---> 27     print(result)
#      28
#      29     # Convert the results to a DataFrame
#
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# c:\ProgramData\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\ProgramData\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
